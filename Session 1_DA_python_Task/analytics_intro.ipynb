# %%
# Task 2
print("My name is Himanshu")
print("My favourite app is Zomato")
# Out:
# My name is Himanshu
# My favourite app is Zomato

# %%
# Task 4
import datetime
print(datetime.datetime.now().year)
# Out:
# 2026
